# %% [markdown]
# # python list assignment

# %% [markdown]
# # using for loop and list comprehension;
# ### 1 print the upper case of fruits in another list
# ### 2 print the upper case of items in the fruit list that does not contain a

# %%
fruits=["apple", "banana" , "cherry" , "kiwi" , "mango" ]

# %%
a=[]
for i in  fruits:
    a.append(i.upper())
print(a)
# Out:
# ['APPLE', 'BANANA', 'CHERRY', 'KIWI', 'MANGO']

# %%
new=[ i for i in a if 'A' not in i]

# %%
new
# Out:
# ['CHERRY', 'KIWI']
