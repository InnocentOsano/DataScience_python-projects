# %% [markdown]
# ### Assignment
# ### 1 create a tuple
# ### 2 Add items to the tuple
# ### 3 Remove items from a tuple

# %%
fruits=( 'mango', 'apple', 'banana', 'watermelon')

# %%
### Add items to a tuple using conversation method
fruits1=list(fruits)
fruits1.append('orange')
fruits=tuple(fruits1)
print(fruits)
# Out:
# ('mango', 'apple', 'banana', 'watermelon', 'orange')

# %%
### method 2-adding a tuple to a tuple
### create a tuple for the item
name=('orange',)
fruits+=name # fruits=fruits+name
print(type (name))
# Out:
# <class 'tuple'>

# %%
print(fruits)
# Out:
# ('apple', 'banana', 'watermelon', 'orange', 'orange')

# %%
### Removing items from a tuple
car=('Toyota', 'Nissan', 'Subaru', 'Mazda')
b=list(car)
b.remove('Toyota')
car=tuple(b)
print(car)
# Out:
# ('Nissan', 'Subaru', 'Mazda')
